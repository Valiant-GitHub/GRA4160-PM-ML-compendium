# %% [markdown]
# # Exam in GRA 4160 (Spring 2025)
# ## Predictive modelling with machine learning
#
# ### 30-hour take-home exam
# #### 26.05.2025 09:00 - 27.05.2025 15:00

# %% [markdown]
# ## Instructions
# Attached to this exam are the following files:
# 1. `Exam_GRA4160_spring2025.ipynb` (this notebook)
# 2. `Hitters.csv`
# 3. `WholesaleCustomers.csv`
# 4. `wdbc.data`
# 5. `wdbc.names`
# 6. `SimulatedData.csv`
#
# The assignments are divided into four sections:
# 1. Predict baseball salaries with regularized regression
# 2. Customer segmentation with clustering (unsupervised learning)
# 3. Ensemble methods for breast cancer prediction
# 4. Predictive classification challenge (simulated data)
#
# Before starting, thoroughly read through all assignments.
# At the beginning of each added cell, explicitly state the exercise you are addressing.
# Ensure the cells are arranged logically and that all code cells execute error-free.
#
# Ensure you document your code with comprehensive comments and explanations to keep it clean and readable.
# **Additionally, strive to make your non-code responses as concise and short as possible.**
# Long responses with irrelevant information can lead to a deduction of points.
# Preferably, put your non-code responses in markdown cells.
#
# Remember to save and back up the notebook periodically.
#
# ### Allowed Aids
# - All course material and your notes.
# - You can use the 3rd party Python libraries we used in class without any explanations (e.g., NumPy, Pandas, Scikit-learn, and PyTorch).
# - Any other 3rd party Python libraries, but you must explain what they do and why you choose to use them.
# - Resources on the Internet, but if you include code pieces you find online you must list the URLs of these resources in the corresponding resources' cell at the end of each section.
# - You are NOT allowed to receive help from other people in solving the assignments.
#
# #### Use of generative AI
# You are allowed to use generative AI tools to generate code snippets, but you must be able to explain all the code you submit in your own words.
# Furthermore, you can use generative AI as an aid for all exercises, but you must then briefly explain why you chose to use generative AI tools and how you used them.
# If you use generative AI tools, you must list the tools you used in the corresponding resources' cell at the end of each section.
#
# ### Submission
# Submit your completed notebook (the `.ipynb` file) via WISEflow before the deadline.
# Be aware that the deadline is strict, so do not wait until the very last minute to submit.
# Don't forget to fill out your student ID at the designated area below!

# %%
## Fill in your student ID here:

# %%
# Standard imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Assignment 1: Predict baseball salaries with regularized regression
#
# This assignment is based on the `Hitters.csv` dataset (originally from the ISLR book; see Kaggle: [Hitters dataset](https://www.kaggle.com/datasets/floser/hitters)).
# It contains various statistics for Major League Baseball players from the 1986 season (and their career totals), along with their salaries in 1987.
# There are 20 features (including performance metrics like hits, home runs, RBIs, etc., and categorical variables for league and division) and 322 players.
# The target variable is the player's annual salary (some values are missing).
# After removing players with missing salary, 263 observations remain.
# The goal is to build regression models to predict a player's salary based on their 1986 performance and other features, and to explore the use of regularization to improve predictions.
#
# **Exercise 1.1:**
# Load the dataset from `Hitters.csv` and display the first five rows.
# Examine the structure of the dataset (features and their types) and report how many observations and features it contains.
# Check for missing values in the dataset.
# If there are missing values, apply an appropriate strategy to handle them.
#
# **Exercise 1.2:**
# Perform an exploratory data analysis on the features.
# Compute summary statistics for the numeric features.
# For the categorical features, show the distribution of categories.
# Based on this initial exploration, which variables do you expect to be most useful in predicting a player's salary, and why?
#
# **Exercise 1.3:**
# Explain the concept of regularization in the context of linear regression.
# What is the key difference between Ridge and Lasso regression?
# Discuss when one might be preferred over the other.
#
# **Exercise 1.4:**
# Prepare the data for modeling.
# This includes encoding categorical variables and standardizing the numeric features.
# Split the data into a training set and a testing set.
#
# **Exercise 1.5:**
# Train an ordinary least squares (OLS) linear regression model on the training data (without regularization).
# Evaluate its performance on the test set using appropriate regression metrics.
# Briefly comment on the model's performance.
#
# **Exercise 1.6:**
# Train a Ridge regression and a Lasso regression model on the training data.
# Use cross-validation on the training set to find the optimal regularization parameter (alpha) for each model.
# Report the chosen alpha values.
# Evaluate the Ridge and Lasso models on the test set (using the same metrics as in 1.5).
#
# **Exercise 1.7:**
# Compare the results of the three models (OLS, Ridge, Lasso).
# Which model performs best on the test data? Discuss the differences in performance and possible reasons.
# Examine the coefficients learned by each model: how do the Ridge and Lasso coefficients differ from the OLS coefficients?
# Did the Lasso model set any coefficients to zero (effectively selecting features)?
# What does this imply about which features are most important?
# Provide an interpretation of the results and any insights on the bias-variance trade-off observed.

# %%
# Solution cell (add more if necesarry)

# %% [markdown]
# #### List of resources used in this section:

# %% [markdown]
# ## Assignment 2: Customer segmentation with clustering (unsupervised learning)
#
# This assignment uses the `WholesaleCustomers.csv` dataset (source: UCI Machine Learning Repository - Wholesale customers data).
# It contains data on annual spending (in monetary units) of 440 clients of a wholesale distributor on various product categories:
# Fresh, Milk, Grocery, Frozen, Detergents_Paper, and Delicassen.
# It also includes two categorical attributes: Region (with values 1, 2, 3 representing different regions) and Channel (1 = Horeca (Hotel/Restaurant/Café), 2 = Retail).
# Our focus will be on using unsupervised learning techniques to discover patterns in the spending profiles of these customers.
#
# **Exercise 2.1:**
# Load the dataset from `WholesaleCustomers.csv` and inspect the first few rows.
# How many observations and features are present? Identify which features are continuous and which are categorical.
# Check for any missing values and handle them if present (the dataset should have none).
#
# **Exercise 2.2:**
# Compute summary statistics for the spending features.
# Identify which categories customers tend to spend the most on, on average, and which categories have the highest variability.
# Also, consider the range of values for each feature.
# Do you think it will be necessary to scale the data for the analyses to follow?
# Explain why or why not.
#
# **Exercise 2.3:**
# Perform Principal Component Analysis (PCA) on the six spending features.
# Before applying PCA, apply an appropriate scaling to the features if you determined it necessary.
# Determine how many principal components are needed to explain, say, 90% of the variance in the data.
# Interpret the first two principal components in terms of the original features.
#
# **Exercise 2.4:**
# Use K-Means clustering to segment the customers based on the spending features.
# Since the optimal number of clusters is not known a priori, use the elbow method and/or the silhouette score to determine a reasonable number of clusters.
#
# **Exercise 2.5:**
# Choose a value of k based on your analysis in 2.4 and perform K-Means clustering with that number of clusters.
# Describe the characteristics of the clusters obtained.
# For each cluster, consider the mean spending in each category and characterize the cluster in understandable terms.
# How many customers fall into each cluster?
#
# **Exercise 2.6:**
# Investigate how the clusters relate to the provided Region and Channel labels.
# For each cluster, determine the distribution of Region and Channel.
# Does this alignment (or lack thereof) make sense and provide additional insight into the cluster profiles?
# Note: since clustering is unsupervised, you did not use these labels in forming clusters, but this comparison can help validate and interpret the clusters.
#
# **Exercise 2.7:**
# Discuss how you would evaluate the quality of the clustering results.
# What metrics or methods can be used to assess whether the clusters found are meaningful?
# Also, reflect on the challenges of evaluating clusters in the absence of ground truth labels.
# In this dataset, do the clusters you found appear to be meaningful groupings of customers?
# Justify your answer.

# %%
# Solution cell (add more if necesarry)

# %% [markdown]
# #### List of resources used in this section:

# %% [markdown]
# ## Assignment 3: Ensemble methods for breast cancer prediction
#
# In this assignment, you are given the breast cancer dataset (`wdbc.data` and `wdbc.names`), which is downloaded from the [UCI Breast Cancer Wisconsin (Diagnostic) dataset](https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic).
# Each record corresponds to a biopsy of a breast tumor, described by 30 numeric features that summarize characteristics of the cell nuclei present in the image (such as radius, texture, perimeter, area, smoothness, compactness, concavity, symmetry, etc.).
# The target variable is the diagnosis: Malignant (M) or Benign (B).
# There are 569 instances in the dataset (212 Malignant, 357 Benign).
# The goal is to build models to predict whether a tumor is malignant or benign from the features, and to explore how ensemble methods can improve classification performance.
#
# **Exercise 3.1:**
# Load the dataset by combining the `wdbc.data` and `wdbc.names` files.
# Report the number of observations and features.
# What are the feature names, and what does the target variable represent?
# Check for class balance in the target: how many malignant vs benign cases are there?
#
# **Exercise 3.2:**
# Split the data into a training set and a test set.
# We will experiment with multiple models, so it's useful to have a dedicated test set for final evaluation.
# Ensure that the class proportion is roughly maintained in the split.
#
# **Exercise 3.3:**
# Train a decision tree classifier on the training data.
# To avoid overfitting, use cross-validation on the training set to determine an appropriate complexity constraint.
# After tuning, fit the decision tree with the chosen parameters on the full training set and report its performance on the test set.
#
# **Exercise 3.4:**
# Train a Random Forest classifier on the training data.
# Evaluate its performance on the test set.
# Compare the Random Forest's test results with the decision tree's results.
#
# **Exercise 3.5:**
# Train a Gradient Boosting classifier on the training data.
# You may need to tune parameters such as the number of estimators or learning rate via cross-validation to get good performance.
# Evaluate the Gradient Boosting model on the test set.
#
# **Exercise 3.6:**
# Compare the performance of the three models (decision tree, random forest, gradient boosting) on the test set.
# Which model performed best, and by how much?
# Discuss these results in terms of the bias-variance trade-off and the advantages of ensemble methods over a single decision tree.
#
# **Exercise 3.7:**
# Identify the most important features for the Random Forest in predicting cancer.
# List the top features and provide an interpretation.
#
# **Exercise 3.8:**
# Briefly explain the difference between how Random Forests and Gradient Boosting classifiers are constructed.
# Why might these ensemble methods yield better predictive performance than a single decision tree?

# %%
# Solution cell (add more if necesarry)

# %% [markdown]
# #### List of resources used in this section:

# %% [markdown]
# ## Assignment 4: Predictive classification challenge (simulated data)
#
# In this assignment, you are given a simulated dataset (`SimulatedData.csv`) for a binary classification task.
# The dataset contains a number of features and a binary target variable.
# The underlying relationship between the features and the target is non-trivial, involving non-linear effects and noise.
# Your job is to analyze this dataset and build a predictive model that can generalize well to unseen data.
#
# *Note:* A separate hold-out test set (of the same format as `SimulatedData.csv`) is withheld and will be used by the grader to evaluate the performance of your final model.
# You will not have access to this test set during the exam, so you should rely on sound validation techniques to estimate your model's performance.
#
# **Exercise 4.1:**
# Load the training dataset from `SimulatedData.csv` and examine its structure.
# How many features does the dataset contain, and what are their types (numeric, categorical)?
# How many instances are there?
# Determine the class distribution (what percentage of instances belong to class 1 vs class 0?).
#
# **Exercise 4.2:**
# Perform an exploratory data analysis on the features with respect to the target.
# This could include:
#
# - Visualizing the distribution of each numeric feature, perhaps separated by class.
# - Checking pairwise relationships between features and the target.
# - If there are categorical features, examining the target proportion within each category level.
#
# Summarize any interesting patterns or observations.
# (Keep in mind that the data is simulated and may have complex non-linear relationships, so individual features might not show obvious linear separation by class.)
#
# **Exercise 4.3:**
# Prepare the data for modeling.
# This includes encoding any categorical variables and scaling the features if necessary.
# Discuss your choices: for example, if you plan to use a tree-based model, you might not need feature scaling; if you use a distance-based or gradient-based model (like k-NN or logistic regression), scaling is important.
#
# **Exercise 4.4:**
# Train at least two different classification models on this dataset.
# For instance, you might choose a simple model like logistic regression or a single decision tree as a baseline, and a more complex model like a random forest, gradient boosting machine, support vector machine, or neural network.
# Justify your choice of models (what different qualities do they have that might be relevant for this task?).
#
# **Exercise 4.5:**
# For each model you chose in 4.4, use appropriate hyperparameter tuning (for example, use cross-validation on the training set or a hold-out validation subset) to find good model parameters.
# Describe the process and criteria you used for tuning.
#
# **Exercise 4.6:**
# Evaluate the performance of your models using appropriate metrics.
# Since this is a binary classification, report metrics such as accuracy, precision, recall, and F1-score for each model.
# If the classes are imbalanced, make sure to consider metrics beyond accuracy.
# Use your cross-validation results or validation set to estimate how the models are likely to perform on unseen data.
# Which model performs the best according to these metrics?
#
# **Exercise 4.7:**
# Compare the models and discuss the results.
# Which model would you choose as the final model to deploy on new data, and why?
# Consider factors such as performance metrics, complexity, and interpretability.
# What does this tell you about the nature of the classification task (e.g., does a more complex model significantly outperform a simpler one, suggesting the decision boundary is complex)?
#
# **Exercise 4.8:**
# Suppose you have settled on a final model.
# Demonstrate how you would use this model to make predictions on a new dataset.
# (For example, you could simulate loading a `SimulatedData_test.csv` and running `model.predict` on it.)
# You don't have the actual test set, but you should ensure that your code is prepared to handle new data with the same features.
# In particular, if you performed any preprocessing in 4.3, make sure your final model pipeline applies those transformations to new data.
# (The grader will use your submitted notebook to run predictions on the hidden test set, so your code should be generalizable.)
#
# **Exercise 4.9:**
# Reflect on the overall modeling process for this task.
# What aspects of the dataset made this classification problem challenging?
# (Think about things like non-linear feature interactions, irrelevant features, etc.)
# How did you address these challenges?
# If your best model is still not perfect, what are some potential ways to further improve performance if you had more time or data?

# %%
# Solution cell (add more if necesarry)

# %% [markdown]
# #### List of resources used in this section:
